# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# f, ax=plt.subplots()
df = pd.read_csv("variety.csv")
sns.boxplot(df, x="price", y="kind", hue="kind", width=.6, palette="RdYlGn")
sns.stripplot(df, x="price", y="kind",color=".3", size=6, jitter=False)
ax.set(ylabel="")
# sns.despine(trim=True, left=True)
#
# Out:
# [Text(4.444444444444445, 0.5, '')]
